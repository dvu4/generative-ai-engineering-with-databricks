# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# # Explore Licensing of Datasets
#
#
# **In this demo, we will focus on reviewing the licenses associated with data we might want to use for our model.** To do this, we will explore the Databricks Marketplace. There, we will review a specific dataset that we might want to use for one of our models and find its licensing information.
#
#
# **Learning Objectives:**
#
# *By the end of this demo, you will be able to;*
#
# * Recognize potential legal concerns over usage of datasets for your AI applications.
#
# * Find datasets for your application in Databricks Marketplace.
#
# * Assess with your legal counsel whether the license for a given dataset would be permit your intended usage.

# %% [markdown]
# ## REQUIRED - SELECT CLASSIC COMPUTE
# Before executing cells in this notebook, please select your classic compute cluster in the lab. Be aware that **Serverless** is enabled by default.
#
# Follow these steps to select the classic compute cluster:
# 1. Navigate to the top-right of this notebook and click the drop-down menu to select your cluster. By default, the notebook will use **Serverless**.
#
# 2. If your cluster is available, select it and continue to the next cell. If the cluster is not shown:
#
#    - Click **More** in the drop-down.
#
#    - In the **Attach to an existing compute resource** window, use the first drop-down to select your unique cluster.
#
# **NOTE:** If your cluster has terminated, you might need to restart it in order to select it. To do this:
#
# 1. Right-click on **Compute** in the left navigation pane and select *Open in new tab*.
#
# 2. Find the triangle icon to the right of your compute cluster name and click it.
#
# 3. Wait a few minutes for the cluster to start.
#
# 4. Once the cluster is running, complete the steps above to select your cluster.

# %% [markdown]
# ## Requirements
#
# Please review the following requirements before starting the lesson:
#
# * To walk through this demo, you simply need a Databricks environment with access to the **[Databricks Marketplace](/marketplace)**.

# %% [markdown]
# ## Demo Overview
#
# The power of modern GenAI applications exists in their ability to become intimately familiar with your enterprise's data. However, there are also use cases where we might want to augment our training data or contextual knowledge data with general industry data. We can find supplementary data using the Databricks Marketplace.
#
# In this demo, we will explore a few datasets on the Databricks Marketplace, with a particular focus on licensing issues and determining whether they'd be a good candidate for using in a particular type of GenAI application.
#
# Here are all the detailed steps:
#
# - Get familiar with Databricks Marketplace and how to find it.
# - Look at the license for an example dataset that would be OK for our application.
# - Explore another example dataset that might not be OK for us to use.

# %% [markdown]
# ## Databricks Marketplace
#
# The Databricks Marketplace allows users to discover, explore, and access data and AI resources from a variety of providers. It offers resources such as datasets you can use to power RAG applications or add as features or attributes to your existing pipelines, pre-trained machine learning models, and solution accelerators to help you get from concept to production more quickly and efficiently.
#
# ![marketplace_home](../Includes/images/marketplace_home.png)
#
# In this demo, we'll be focused on datasets we can use for our RAG application.
#
# There are **two main reasons** we might want to find additional data for our RAG application:
#
# 1. We might want additional reference data to augment our prompt as context that we can query at runtime using Vector Search against a vector index.
# 2. In some scenarios, we may need additional data to use for fine-tuning or further pretraining the LLM powering our overall RAG application – note that this can also be applied outside of RAG applications.
#
# ### Why do we want third-party data?
#
# It's true that a lot of your application's contextual data is likely to come from within your company. However, there might be times when information provided by third-party providers can be useful as well. We need to make sure that we're allowed to use that data.
#
# As practitioners, it is critical to be aware of potential licensing restrictions that these datasets may ship with that could prevent you from using that particular dataset for your intended purpose. Every dataset on the Databricks Marketplace should have a license that you can review to determine (along with your appropriate legal counsel) whether it is usable or not.
#
# **Note:** While the focus here is on Databricks Marketplace, the same ideas are equally applicable to data you find anywhere else on the interface, including other data hubs like the one hosted and operated by Hugging Face. Regardless of where you find data for your application, be sure you know the licensing and legal implications.

# %% [markdown]
# ## Bright Data Amazon Reviews Dataset
#
# In the first example, we'll look at an Amazon Reviews dataset provided by Bright Data.
#
# To locate the dataset, follow the below steps:
#
# 1. Navigate to the Databricks Marketplace
# 2. Filter the **Product** filter to "Tables"
# 3. Filter the **Provider** filter to "Bright Data"
# 4. Open the "Amazon - Best Seller Products /Reviews/Products Dataset"
#
# ![bright_data_amazon_reviews_dataset_overview](../Includes/images/bright_data_amazon_reviews_dataset_overview.png)
#
# Let's explore the data to see if it could work for our use case:
#
# * What is the record-level of the dataset?
# * What fields does it include?
# * How many records does it have?
# * How often is the data updated?
#
# Even if the dataset meets our requirements, we need to review its **license** to determine whether or not we're allowed to use it.
#
# To find the license information:
#
# 1. Take a look at the **Product links** section under the provider info
# 2. Click on **License** to open the license information
# 3. Review the agreement for something like "Acceptable Use"
#
# You'll need to carefully review the license to determine whether it permits your intended purpose with your application. It is highly recommended to take advantage of legal counsel in making any licensing determination.

# %% [markdown]
# ## Rearc Personal Income | FRED
#
# In the next example, we'll look at a Personal Income dataset from Rearc.
#
# ![rearc_personal_income_fred_overview](../Includes/images/rearc_personal_income_fred_overview.png)
#
#
# Let's get started with a few questions:
#
# * How would this data be useful for a GenAI application?
# * Where is the license information?
# * Are we able to use this data for a hypothetical commercial application?
#
# The same advice applies here. Carefully review the license, ideally with the help of appropriate legal counsel before integrating the data into your application or using it to train or fine-tune your models.
#
# ### Ingesting the Data
#
# Let's assume we have legal permission to use the data for our use case.
#
# We can ingest it into our environment directly from Databricks Marketplace by clicking the **Get instant access** button on the dataset page in Marketplace.
#
# This will prompt us to:
#
# * determine the name of the catalog in which the data will reside (new or existing).
# * accept the terms and conditions.
#
# And then we'll be able to open, explore, and use our data!

# %%
rearc_personal_income_fred = spark.sql("SELECT * FROM  rearc_personal_income_fred.fs_fred.fred_pi")
rearc_personal_income_fred.limit(10).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>DATE</th><th>PI</th></tr></thead><tbody><tr><td>1959-01-01</td><td>391.8</td></tr><tr><td>1959-02-01</td><td>393.7</td></tr><tr><td>1959-03-01</td><td>396.5</td></tr><tr><td>1959-04-01</td><td>399.9</td></tr><tr><td>1959-05-01</td><td>402.4</td></tr><tr><td>1959-06-01</td><td>404.8</td></tr><tr><td>1959-07-01</td><td>405.4</td></tr><tr><td>1959-08-01</td><td>403.7</td></tr><tr><td>1959-09-01</td><td>405.1</td></tr><tr><td>1959-10-01</td><td>406.6</td></tr></tbody></table></div>

# %%
rearc_personal_income_fred_schema = spark.sql("SELECT * FROM rearc_personal_income_fred.information_schema.columns")
display(rearc_personal_income_fred_schema)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>table_catalog</th><th>table_schema</th><th>table_name</th><th>column_name</th><th>ordinal_position</th><th>column_default</th><th>is_nullable</th><th>full_data_type</th><th>data_type</th><th>character_maximum_length</th><th>character_octet_length</th><th>numeric_precision</th><th>numeric_precision_radix</th><th>numeric_scale</th><th>datetime_precision</th><th>interval_type</th><th>interval_precision</th><th>maximum_cardinality</th><th>is_identity</th><th>identity_generation</th><th>identity_start</th><th>identity_increment</th><th>identity_maximum</th><th>identity_minimum</th><th>identity_cycle</th><th>is_generated</th><th>generation_expression</th><th>is_system_time_period_start</th><th>is_system_time_period_end</th><th>system_time_period_timestamp_generation</th><th>is_updatable</th><th>partition_index</th><th>comment</th></tr></thead><tbody><tr><td>rearc_personal_income_fred</td><td>fs_fred</td><td>fred_pi</td><td>DATE</td><td>0</td><td>null</td><td>YES</td><td>string</td><td>STRING</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>NO</td><td>NO</td><td>null</td><td>YES</td><td>null</td><td>null</td></tr><tr><td>rearc_personal_income_fred</td><td>fs_fred</td><td>fred_pi</td><td>PI</td><td>1</td><td>null</td><td>YES</td><td>string</td><td>STRING</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>NO</td><td>NO</td><td>null</td><td>YES</td><td>null</td><td>null</td></tr><tr><td>rearc_personal_income_fred</td><td>information_schema</td><td>catalog_privileges</td><td>grantor</td><td>0</td><td>null</td><td>NO</td><td>string</td><td>STRING</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>NO</td><td>NO</td><td>null</td><td>YES</td><td>null</td><td>Principal that granted the privilege.</td></tr><tr><td>rearc_personal_income_fred</td><td>information_schema</td><td>catalog_privileges</td><td>grantee</td><td>1</td><td>null</td><td>NO</td><td>string</td><td>STRING</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>NO</td><td>NO</td><td>null</td><td>YES</td><td>null</td><td>Principal to which the privilege is granted.</td></tr><tr><td>rearc_personal_income_fred</td><td>information_schema</td><td>catalog_privileges</td><td>catalog_name</td><td>2</td><td>null</td><td>NO</td><td>string</td><td>STRING</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>NO</td><td>NO</td><td>null</td><td>YES</td><td>null</td><td>Catalog on which the privilege is granted.</td></tr><tr><td>rearc_personal_income_fred</td><td>information_schema</td><td>catalog_privileges</td><td>privilege_type</td><td>3</td><td>null</td><td>NO</td><td>string</td><td>STRING</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>NO</td><td>NO</td><td>null</td><td>YES</td><td>null</td><td>Privilege being granted.</td></tr><tr><td>rearc_personal_income_fred</td><td>information_schema</td><td>catalog_priv ...

# %%
import pyspark.sql.functions as F

yahoo_finance_business_dataset = spark.sql("SELECT * FROM  bright_data_yahoo_finance_business_dataset.datasets.yahoo_finance_business")
yahoo_finance_business_dataset.display()
yahoo_finance_business_dataset.groupBy("ENTITY_TYPE").count().display()
yahoo_finance_business_dataset.where(F.col("STOCK_TICKER").contains("ROKU")).display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>NAME</th><th>COMPANY_ID</th><th>ENTITY_TYPE</th><th>SUMMARY</th><th>STOCK_TICKER</th><th>CURRENCY</th><th>EARNINGS_DATE</th><th>EXCHANGE</th><th>CLOSING_PRICE</th><th>PREVIOUS_CLOSE</th><th>OPEN</th><th>BID</th><th>ASK</th><th>DAY_RANGE</th><th>WEEK_RANGE</th><th>VOLUME</th><th>URL</th><th>PEOPLE_ALSO_WATCH</th><th>SIMILAR</th></tr></thead><tbody><tr><td>Schroder International Selectio</td><td>0P0001IRNA.F</td><td>MUTUALFUND</td><td>Frankfurt - Frankfurt Delayed Price. Currency in EUR</td><td>0P0001</td><td>EUR</td><td>null</td><td>DOWN</td><td>165.616</td><td>166.77</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>https://finance.yahoo.com/quote/0P0001IRNA.F/summary/</td><td>null</td><td>null</td></tr><tr><td>Nasdaq ASPA Industrial Goods an</td><td>^NQASPA5020JPYT</td><td>INDEX</td><td>Nasdaq GIDS - Nasdaq GIDS Real Time Price. Currency in JPY</td><td>NQASPA</td><td>JPY</td><td>null</td><td>DOWN</td><td>2195.0457</td><td>2195.05</td><td>null</td><td>null</td><td>null</td><td>2,195.05 - 2,195.05</td><td>2,195.05 - 2,195.05</td><td>null</td><td>https://finance.yahoo.com/quote/^NQASPA5020JPYT/summary/</td><td>null</td><td>null</td></tr><tr><td>Arco Vara Kinnisvarabüroo AS</td><td>AV1.SG</td><td>EQUITY</td><td>Stuttgart - Stuttgart Delayed Price. Currency in EUR</td><td>AV1.SG</td><td>EUR</td><td>N/A</td><td>DOWN</td><td>1.51</td><td>1.57</td><td>1.525</td><td>1.5100 x 100000</td><td>1.7550 x 100000</td><td>1.5100 - 1.5500</td><td>1.5100 - 1.8920</td><td>null</td><td>https://finance.yahoo.com/quote/AV1.SG/summary/</td><td>null</td><td>[{"change":0.03,"last_price":1.61,"perc_change":"-1.83%","symbol":"AV1.F"}]</td></tr><tr><td>Veritas - ETF-PORTFOLIO GLOBAL</td><td>FGUV.SG</td><td>MUTUALFUND</td><td>Stuttgart - Stuttgart Delayed Price. Currency in EUR</td><td>FGUV.SG</td><td>EUR</td><td>null</td><td>DOWN</td><td>20.964</td><td>21.08</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>https://finance.yahoo.com/quote/FGUV.SG/summary/</td><td>null</td><td>null</td></tr><tr><td>SENTRY SELECT PRIMARY METALS CO</td><td>PME.TO</td><td>EQUITY</td><td>Toronto - Toronto Real Time Price. Currency in CAD</td><td>PME.TO</td><td>CAD</td><td>N/A</td><td>UP</td><td>2.42</td><td>2.36</td><td>2.37</td><td>2.3800 x 0</td><td>2.4200 x 0</td><td>2.3700 - 2.4200</td><td>2.0600 - 2.8800</td><td>2700</td><td>https://finance.yahoo.com/quote/PME.TO/summary/</td><td>null</td><td>null</td></tr><tr><td>Latour Investment AB</td><td>18LB.SG</td><td>EQUITY</td><td>Stuttgart - Stuttgart Delayed Price. Currency in EUR</td><td>18LB.SG</td><td>EUR</td><td>N/A</td><td>UP</td><td>16.17</td><td>16.06</td><td>16.25</td><td>16.23 x 0</td><td>16.39 x 0</td><td>16.07 - 16.25</td><td>14.86 - 21.23</td><td>null</td><td>https://finance.yahoo.com/quote/18LB.SG/summary/</td><td>null</td><td>null</td></tr><tr><td>Nasdaq N America Telecommunicat</td><td>^NQNA15LMT</td><td>INDEX</td><td>Nasdaq GIDS - Nasdaq GIDS Real Time Price. Currency in USD</td><td>NQNA15</td><td>USD</td><td>null</td><td>DOWN</td><td>1530.1262</td><td>1532.85</td><td>null</td><td>null</td><td>null</td><td>1,528.86 - 1,538.97</td><td>1,528.86 - 1,538.97</td><td>null</td><td>https://finance.yahoo.com/quote/^NQNA15LMT/summary/</td><td>null</td><td>null</td></tr><tr><td>Nasdaq US Benchmark Electrical</td><td>^NQUSB50202010JPYN</td><td>INDEX</td><td>Nasdaq GIDS - Nasdaq GIDS Real Time Price. Currency in JPY</td><td>NQUSB5</td><td>JPY</td><td>null</td><td>DOWN</td><td>1971.6653</td><td>1971.67</td><td>null</td><td>null</td><td>null</td><td>1,971.67 - 1,971.67</td><td>1,971.67 - 1,971.67</td><td>null</td><td>https://finance.yahoo.com/quote/^NQUSB50202010JPYN/summary/</td><td>null</td><td>null</td></tr><tr><td>DWS I.-LAT.AM.EQU. LC</td><td>FP7W.DU</td><td>ETF</td><td>Dusseldorf - Dusseldorf Delayed Price. Currency in EUR</td><td>FP ...
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>ENTITY_TYPE</th><th>count</th></tr></thead><tbody><tr><td>ETF</td><td>93</td></tr><tr><td>INDEX</td><td>263</td></tr><tr><td>CURRENCY</td><td>7</td></tr><tr><td>FUTURE</td><td>2</td></tr><tr><td>EQUITY</td><td>272</td></tr><tr><td>MUTUALFUND</td><td>359</td></tr><tr><td>null</td><td>4</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>NAME</th><th>COMPANY_ID</th><th>ENTITY_TYPE</th><th>SUMMARY</th><th>STOCK_TICKER</th><th>CURRENCY</th><th>EARNINGS_DATE</th><th>EXCHANGE</th><th>CLOSING_PRICE</th><th>PREVIOUS_CLOSE</th><th>OPEN</th><th>BID</th><th>ASK</th><th>DAY_RANGE</th><th>WEEK_RANGE</th><th>VOLUME</th><th>URL</th><th>PEOPLE_ALSO_WATCH</th><th>SIMILAR</th></tr></thead><tbody><tr><td>ROKU INC</td><td>ROKU.MX</td><td>EQUITY</td><td>Mexico - Mexico Delayed Price. Currency in MXN</td><td>ROKU.MX</td><td>MXN</td><td>Oct 31, 2023 - Nov 06, 2023</td><td>DOWN</td><td>1191</td><td>1243.52</td><td>null</td><td>1,180.01 x N/A</td><td>1,260.00 x N/A</td><td>1,191.00 - 1,194.37</td><td>752.00 - 1,656.68</td><td>26</td><td>https://finance.yahoo.com/quote/ROKU.MX/summary/</td><td>[{"change":13,"last_price":772,"perc_change":"-1.66%","symbol":"SQ.MX"},{"change":18.4,"last_price":995.01,"perc_change":"-1.82%","symbol":"PYPL.MX"},{"change":7.85,"last_price":1646.61,"perc_change":"-0.47%","symbol":"AMD.MX"},{"change":76.95,"last_price":7155.52,"perc_change":"+1.09%","symbol":"NVDA.MX"},{"change":null,"last_price":1192.01,"perc_change":"0.00%","symbol":"ZM.MX"}]</td><td>[{"change":0.51,"last_price":66.86,"perc_change":"-0.76%","symbol":"R35.F"},{"change":46.1,"last_price":6567,"perc_change":"-0.70%","symbol":"NFLX.MX"},{"change":0.22,"last_price":79.75,"perc_change":"-0.28%","symbol":"LYV"},{"change":2.36,"last_price":69.27,"perc_change":"-3.29%","symbol":"ROKU"}]</td></tr></tbody></table></div>

# %%
yahoo_finance_business_schema = spark.sql(
    "SELECT * FROM bright_data_yahoo_finance_business_dataset.information_schema.columns"
)
display(yahoo_finance_business_schema)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>table_catalog</th><th>table_schema</th><th>table_name</th><th>column_name</th><th>ordinal_position</th><th>column_default</th><th>is_nullable</th><th>full_data_type</th><th>data_type</th><th>character_maximum_length</th><th>character_octet_length</th><th>numeric_precision</th><th>numeric_precision_radix</th><th>numeric_scale</th><th>datetime_precision</th><th>interval_type</th><th>interval_precision</th><th>maximum_cardinality</th><th>is_identity</th><th>identity_generation</th><th>identity_start</th><th>identity_increment</th><th>identity_maximum</th><th>identity_minimum</th><th>identity_cycle</th><th>is_generated</th><th>generation_expression</th><th>is_system_time_period_start</th><th>is_system_time_period_end</th><th>system_time_period_timestamp_generation</th><th>is_updatable</th><th>partition_index</th><th>comment</th></tr></thead><tbody><tr><td>bright_data_yahoo_finance_business_dataset</td><td>datasets</td><td>yahoo_finance_business</td><td>NAME</td><td>0</td><td>null</td><td>YES</td><td>string</td><td>STRING</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>NO</td><td>NO</td><td>null</td><td>YES</td><td>null</td><td>null</td></tr><tr><td>bright_data_yahoo_finance_business_dataset</td><td>datasets</td><td>yahoo_finance_business</td><td>COMPANY_ID</td><td>1</td><td>null</td><td>YES</td><td>string</td><td>STRING</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>NO</td><td>NO</td><td>null</td><td>YES</td><td>null</td><td>null</td></tr><tr><td>bright_data_yahoo_finance_business_dataset</td><td>datasets</td><td>yahoo_finance_business</td><td>ENTITY_TYPE</td><td>2</td><td>null</td><td>YES</td><td>string</td><td>STRING</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>NO</td><td>NO</td><td>null</td><td>YES</td><td>null</td><td>null</td></tr><tr><td>bright_data_yahoo_finance_business_dataset</td><td>datasets</td><td>yahoo_finance_business</td><td>SUMMARY</td><td>3</td><td>null</td><td>YES</td><td>string</td><td>STRING</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>NO</td><td>NO</td><td>null</td><td>YES</td><td>null</td><td>null</td></tr><tr><td>bright_data_yahoo_finance_business_dataset</td><td>datasets</td><td>yahoo_finance_business</td><td>STOCK_TICKER</td><td>4</td><td>null</td><td>YES</td><td>string</td><td>STRING</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>NO</td><td>NO</td><td>null</td><td>YES</td><td>null</td><td>null</td></tr><tr><td>bright_data_yahoo_finance_business_dataset</td><td>datasets</td><td>yahoo_finance_business</td><td>CURRENCY</td><td>5</td><td>null</td><td>YES</td><td>string</td><td>STRING</td><td>0</td><td>0</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>null</td><td>NO</td><td>null</td><td>NO</td><td>NO</td><td>null</td><td>YES</td><td>null</td><td>null</td></tr><tr><td>bright_data_yahoo_finance_business_dataset</td><td>datasets</td><td>yahoo_finance_business< ...

# %% [markdown]
# ## Conclusion
#
# Before you use any external dataset for your application, you need to review the licensing information under which it is provided. Data made available through the Databricks Marketplace should always have a place to find the license information, which we recommend you review yourself as a practitioner as well as with the advice of appropriate legal counsel. Other popular hubs such as Hugging Face should also have license information available for each dataset.

# %% [markdown]
# &copy; 2025 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
