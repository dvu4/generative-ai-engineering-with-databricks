# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# # LAB - Assembling a RAG Application
#
# In this lab, we will assemble a Retrieval-augmented Generation (RAG) application using the components we previously created. The primary goal is to create a seamless pipeline where users can ask questions, and our system retrieves relevant documents from a Vector Search index to generate informative responses.
#
#
# **Lab Outline:**
#
# In this lab, you will need to complete the following tasks;
#
# * **Task 1 :** Setup the Retriever Component
#
# * **Task 2 :** Setup the Foundation Model
#
# * **Task 3 :** Assemble the Complete RAG Solution
#
# * **Task 4 :** Save the Model to Model Registry in Unity Catalog
#
# **📝 Your task:** Complete the **`<FILL_IN>`** sections in the code blocks and follow the other steps as instructed.

# %% [markdown]
# ## REQUIRED - SELECT CLASSIC COMPUTE
# Before executing cells in this notebook, please select your classic compute cluster in the lab. Be aware that **Serverless** is enabled by default.
#
# Follow these steps to select the classic compute cluster:
# 1. Navigate to the top-right of this notebook and click the drop-down menu to select your cluster. By default, the notebook will use **Serverless**.
#
# 2. If your cluster is available, select it and continue to the next cell. If the cluster is not shown:
#
#    - Click **More** in the drop-down.
#
#    - In the **Attach to an existing compute resource** window, use the first drop-down to select your unique cluster.
#
# **NOTE:** If your cluster has terminated, you might need to restart it in order to select it. To do this:
#
# 1. Right-click on **Compute** in the left navigation pane and select *Open in new tab*.
#
# 2. Find the triangle icon to the right of your compute cluster name and click it.
#
# 3. Wait a few minutes for the cluster to start.
#
# 4. Once the cluster is running, complete the steps above to select your cluster.

# %% [markdown]
# ## Requirements
#
# Please review the following requirements before starting the lesson:
#
# * To run this notebook, you need to use one of the following Databricks runtime(s): **17.3.x-cpu-ml-scala2.13**
#
# **🚨 Important:** This lab relies on the resources established in the previous one. Please ensure you have completed the prior lab before starting this one.

# %% [markdown]
# ## Classroom Setup
#
# Before starting the lab, run the provided classroom setup script. This script will define configuration variables necessary for the lab. Execute the following cell:

# %%
# %pip install -U -qqq databricks-sdk databricks-vectorsearch 'mlflow-skinny[databricks]==3.4.0' langchain==0.3.26 databricks-langchain==0.8.0 PyPDF2==3.0.0 flashrank
# %restart_python
# Out:
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %run ../Includes/Classroom-Setup-04
# Out:
# The examples and models presented in this course are intended solely for demonstration and educational purposes.
#  Please note that the models and prompt examples may sometimes contain offensive, inaccurate, biased, or harmful content.

# %% [markdown]
# **Other Conventions:**
#
# Throughout this demo, we'll refer to the object `DA`. This object, provided by Databricks Academy, contains variables such as your username, catalog name, schema name, working directory, and dataset locations. Run the code block below to view these details:

# %%
print(f"Username:          {DA.username}")
print(f"Catalog Name:      {DA.catalog_name}")
print(f"Schema Name:       {DA.schema_name}")
print(f"Working Directory: {DA.paths.working_dir}")
print(f"Dataset Location:  {DA.paths.datasets}")
# Out:
# Username:          labuser12293781_1761690681@vocareum.com
# Catalog Name:      dbacademy
# Schema Name:       labuser12293781_1761690681
# Working Directory: /Volumes/dbacademy/ops/labuser12293781_1761690681@vocareum_com
# Dataset Location:  NestedNamespace (arxiv='/Volumes/dbacademy_arxiv/v01', dais='/Volumes/dbacademy_dais/v01', news='/Volumes/dbacademy_news/v01', docs='/Volumes/dbacademy_docs/v01')

# %% [markdown]
# ## Task 1: Setup the Retriever Component
# **Steps:**
# 1. Define the embedding model.
# 1. Get the vector search index that was created in the previous lab.
# 1. Generate a **retriever** from the vector store. The retriever should return **three results.**
# 1. Write a test prompt and show the returned search results.

# %%
## Components we created before
vs_endpoint_prefix = "vs_endpoint_"
vs_endpoint_name = vs_endpoint_prefix+str(get_fixed_integer(DA.unique_name("_")))
print(f"Assigned Vector Search endpoint name: {vs_endpoint_name}.")

vs_index_fullname = f"{DA.catalog_name}.{DA.schema_name}.lab_pdf_text_managed_vs_index"
# Out:
# Assigned Vector Search endpoint name: vs_endpoint_3.

# %%
from databricks.vector_search.client import VectorSearchClient
from databricks_langchain import DatabricksEmbeddings
from langchain_core.runnables import RunnableLambda
from langchain.docstore.document import Document
from flashrank import Ranker, RerankRequest


def get_retriever(cache_dir=f"{DA.paths.working_dir}/opt"):

    def retrieve(query, k: int=10):
        if isinstance(query, dict):
            query = next(iter(query.values()))

        ## get the vector search index
        vsc = VectorSearchClient(disable_notice=True)
        vs_index = vsc.get_index(endpoint_name=vs_endpoint_name, index_name=vs_index_fullname)

        # get the query vector
        embeddings = DatabricksEmbeddings(endpoint="databricks-gte-large-en")
        query_vector = embeddings.embed_query(query)
        
        ## get similar k documents
        return query, vs_index.similarity_search_with_score(
            query_vector=query_vector,
            columns=["pdf_name", "content"],
            num_results=k)


    def rerank(query, retrieved, cache_dir, k: int=2):
        ## format result to align with reranker lib format 
        passages = []
        for doc in retrieved.get("result", {}).get("data_array", []):
            new_doc = {"file": doc[0], "text": doc[1]}
            passages.append(new_doc)       
        ## Load the flashrank ranker
        ranker = Ranker(model_name="rank-T5-flan", cache_dir=cache_dir)

        ## rerank the retrieved documents
        rerankrequest = RerankRequest(query=query, passages=passages)
        results = ranker.rerank(rerankrequest)[:k]

        ## format the results of rerank to be ready for prompt
        return [Document(page_content=r.get("text"), metadata={"source": r.get("file")}) for r in results]

    ## the retriever is a runnable sequence of retrieving and reranking.
    return RunnableLambda(retrieve) | RunnableLambda(lambda x: rerank(x[0], x[1], cache_dir))


## test your retriever
question = {"input": "Will Generative AI replace humans especially in workfoce and how can human survive ?"}
vectorstore = get_retriever()
similar_documents = vectorstore.invoke(question)
print(f"Relevant documents: {similar_documents}")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761698038.280570   20039 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761698038.286539   20039 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1761698038.301735   20039 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761698038.301752   20039 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761698038.301755   20039 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1761698038.301757   20039 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# [2025-10-29 00:34:00,600] [WARNING] [real_accelerator.py:194:get_accelerator] Setting accelerator to CPU. If you have GPU or other accelerator, we were unable to detect it.
# [2025-10-29 00:34:00,601] [INFO] [real_accelerator.py:239:get_accelerator] Setting ds_accelerator to cpu (auto detect)
# /usr/bin/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
# Trace(trace_id=tr-6a6f2b13103425f57109a96826c3c3ed)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/databricks/vector_search/utils.py:174, in RequestUtils.issue_request(url, method, token, params, json, verify, auth, data, headers, total_retries, backoff_factor, backoff_jitter)
#     173 try:
# --> 174     response.raise_for_status()
#     175 except Exception as e:
#
# File /databricks/python/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://oregon.cloud.databricks.com/api/2.0/vector-search/endpoints/vs_endpoint_3/indexes/dbacademy.labuser12293781_1761690681.lab_pdf_text_managed_vs_index
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# File <command-7610053130095865>, line 52
#      50 question = {"input": "Will Generative AI replace humans especially in workfoce and how can human survive ?"}
#      51 vectorstore = get_retriever()
# ---> 52 similar_documents = vectorstore.invoke(question)
#      53 print(f"Relevant documents: {similar_documents}")
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:3244, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3242 with set_config_context(config) as context:
#    3243     if i == 0:
# -> 3244         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3245     else:
#    3246         input_ = context.run(step.invoke, input_, config)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:5025, in RunnableLambda.invoke(self, input, config, **kwargs)
#    5010 """Invoke this ``Runnable`` synchronously.
#    5011
#    5012 Args:
#    (...)
#    5022
#    5023 """
#    5024 if hasattr(self, "func"):
# -> 5025     return self._call_with_config(
#    5026         self._invoke,
#    5027         input,
#    5028         ensure_config(config),
#    5029         **kwargs,
#    5030     )
#    5031 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    5032 raise TypeError(msg)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:2092, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2088     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2089     with set_config_context(child_config) as context:
#    2090         output = cast(
#    2091             "Output",
# -> 2092             context.run(
#    2093                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2094                 func,
#    2095                 input_,
#    2096                 config,
#    2097                 run_manager,
#    2098                 **kwargs,
#    2099             ),
#    2100         )
#    2101 except BaseException as e:
#    2102     run_manager.on_chain_error(e)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/config.py:430, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     428 if run_manager is not None and accepts_run_manager(func):
#     429     kwargs["run_manager"] = run_manager
# --> 430 return func(input, **kwargs)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:4882, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4880                 output = chunk
#    4881 else:
# -> 4882     output = call_func_with_variable_args(
#    4883         self.func, input_, config, run_manager, **kwargs
#    4884     )
#    4885 # If the output is a Runnable, invoke it
#    4886 if isinstance(output, Runnable):
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/config.py:430, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     428 if run_manager is not None and accepts_run_manager(func):
#     429     kwargs["run_manager"] = run_manager
# --> 430 return func(input, **kwargs)
#
# File <command-7610053130095865>, line 16, in get_retriever.<locals>.retrieve(query, k)
#      14 ## get the vector search index
#      15 vsc = VectorSearchClient(disable_notice=True)
# ---> 16 vs_index = vsc.get_index(endpoint_name=vs_endpoint_name, index_name=vs_index_fullname)
#      18 # get the query vector
#      19 embeddings = DatabricksEmbeddings(endpoint="databricks-gte-large-en")
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/databricks/vector_search/client.py:696, in VectorSearchClient.get_index(self, endpoint_name, index_name)
#     689 """
#     690 Get an index.
#     691
#     692 :param Option[str] endpoint_name: The optional name of the endpoint.
#     693 :param str index_name: The name of the index.
#     694 """
#     695 assert index_name, "Index name must be specified"
# --> 696 resp = RequestUtils.issue_request(
#     697     url=self._get_index_url(endpoint_name, index_name),
#     698     token=self._get_token_for_request(),
#     699     method="GET",
#     700 )
#     701 index_url = resp.get("status", {}).get("index_url")
#     702 response_endpoint_name = resp.get("endpoint_name")
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/databricks/vector_search/utils.py:176, in RequestUtils.issue_request(url, method, token, params, json, verify, auth, data, headers, total_retries, backoff_factor, backoff_jitter)
#     174     response.raise_for_status()
#     175 except Exception as e:
# --> 176     raise Exception(
#     177         f"Response content {response.content}, status_code {response.status_code}"
#     178     )
#     179 return response.json()
#
# Exception: Response content b'{"error_code":"RESOURCE_DOES_NOT_EXIST","message":"Unity Catalog entity dbacademy.labuser12293781_1761690681.lab_pdf_text_managed_vs_index does not exist.","details":[{"@type":"type.googleapis.com/google.rpc.RequestInfo","request_id":"a5d71bb7-26ee-44b3-aa4b-69d83452a201","serving_data":""}]}', status_code 404

# %% [markdown]
# ## Task 2: Setup the Foundation Model
# **Steps:**
# 1. Define the foundation model for generating responses. Use `llama-3.3` as foundation model.
# 2. Test the foundation model to ensure it provides accurate responses.

# %%
## import necessary libraries
from databricks_langchain import ChatDatabricks

## define foundation model for generating responses
chat_model = ChatDatabricks(endpoint="databricks-meta-llama-3-3-70b-instruct", max_tokens = 500)

## test foundation model
print(f"Test chat model: {chat_model.invoke('Will Generative AI replace humans especially in workfoce?')}")
# Out:
# Test chat model: content="The impact of Generative AI on the workforce is a topic of ongoing debate. While AI has the potential to automate certain tasks and augment human capabilities, it's unlikely to completely replace humans in the workforce. Here's a balanced view:\n\n**Tasks that might be automated:**\n\n1. **Repetitive and routine tasks**: Generative AI can perform tasks that involve processing and generating large amounts of data, such as data entry, bookkeeping, or document processing.\n2. **Simple decision-making**: AI can make decisions based on predefined rules and patterns, which might replace human judgment in certain tasks, like customer service chatbots or basic content moderation.\n3. **Content creation**: AI-generated content, such as articles, social media posts, or even entire books, might become more prevalent, potentially replacing some human writers and content creators.\n\n**Tasks that are less likely to be automated:**\n\n1. **Complex decision-making**: Human judgment, empathy, and critical thinking are still essential for tasks that require nuanced decision-making, such as strategic planning, counseling, or conflict resolution.\n2. **Creative and innovative work**: While AI can generate content, human creativity, originality, and innovation are still unique strengths that AI systems lack.\n3. **High-touch and interpersonal roles**: Jobs that require human interaction, empathy, and building relationships, such as teaching, nursing, or sales, are less likely to be automated.\n4. **Specialized and expert knowledge**: Professions that require specialized knowledge, expertise, and experience, like medicine, law, or engineering, will continue to rely on human professionals.\n\n**New job opportunities and changes in the workforce:**\n\n1. **AI training and development**: As AI becomes more prevalent, there will be a growing need for professionals who can develop, train, and fine-tune AI models.\n2. **AI ethics and governance**: The increasing use of AI will require experts to ensure that AI systems are fair, transparent, and accountable.\n3. **Human-AI collaboration**: The future workforce will likely involve humans and AI systems working together, with AI augmenting human capabilities and humans providing oversight and guidance.\n4. **New industries and job categories**: Generative AI might create new industries and job categories that we cannot yet anticipate, just as the internet and mobile devices have done in the past.\n\n**Mitigating the impact of automation:**\n\n1. **Upskilling and reskilling**: Governments, educational institutions, and employers can invest in programs that" additional_kwargs={} response_metadata={'usage': {'prompt_tokens': 22, 'completion_tokens': 500, 'total_tokens': 522}, 'prompt_tokens': 22, 'completion_tokens': 500, 'total_tokens': 522, 'model': 'meta-llama-3.3-70b-instruct-121024', 'model_name': 'meta-llama-3.3-70b-instruct-121024', 'finish_reason': 'length'} id='run--b2521e33-3591-4bf9-92ab-34a44fb6e70b-0'
# Trace(trace_id=tr-5e08eda4c69d78f85c054265a1a49be5)

# %% [markdown]
# ##Task 3: Assemble the Complete RAG Solution
# **Steps:**
# 1. Merge the retriever and foundation model into a single Langchain chain.
# 2. Configure the Langchain chain with proper templates and context for generating responses.
# 3. Test the complete RAG solution with sample queries.

# %%
from operator import itemgetter
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableLambda, RunnableParallel, RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# Prompt template
TEMPLATE = """You are an assistant for GENAI teaching class. You are answering questions related to Generative AI and how it impacts humans life. If the question is not related to one of these topics, kindly decline to answer. 
Use the following pieces of context to answer the question at the end:

<context>
{context}
</context>

Question: {input}

Answer:
"""

prompt = ChatPromptTemplate.from_template(TEMPLATE)  

# Helper functions
def format_docs(docs):
    # what the model sees in {context}
    return "\n\n".join(d.page_content for d in docs)

def unwrap(payload):
    # return both answer and normalized context (dicts) like you wanted
    docs = payload["docs"]
    return {
        "answer": payload["answer"],
        "context": [{"metadata": getattr(d, "metadata", {}), "page_content": getattr(d, "page_content", "")}
                    for d in docs],
    }

# ---- build the chain ----
# Step 1: retrieve docs
retrieve = RunnableParallel(input=RunnablePassthrough(), docs=get_retriever())

# Step 2: pass formatted context + input to the model
rag = retrieve | {
    "input": itemgetter("input"),
    "context": RunnableLambda(lambda x: format_docs(x["docs"]))
} | prompt | chat_model | StrOutputParser()

# Keep docs for postprocessing
chain = retrieve | {
    "answer": ({"input": itemgetter("input"), "context": RunnableLambda(lambda x: format_docs(x["docs"]))}
               | prompt | chat_model | StrOutputParser()),
    "docs": itemgetter("docs"),
} | RunnableLambda(unwrap)

# Test the complete RAG solution with sample query
question = {"input": "Will Generative AI replace humans especially in workfoce?"}
response = chain.invoke(question)
print(response['answer'])
# Out:
# Trace(trace_id=tr-03331da6340316efeee3aab2e4d61248)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/databricks/vector_search/utils.py:174, in RequestUtils.issue_request(url, method, token, params, json, verify, auth, data, headers, total_retries, backoff_factor, backoff_jitter)
#     173 try:
# --> 174     response.raise_for_status()
#     175 except Exception as e:
#
# File /databricks/python/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://oregon.cloud.databricks.com/api/2.0/vector-search/endpoints/vs_endpoint_3/indexes/dbacademy.labuser12293781_1761690681.lab_pdf_text_managed_vs_index
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# File <command-7610053130095869>, line 54
#      52 # Test the complete RAG solution with sample query
#      53 question = {"input": "Will Generative AI replace humans especially in workfoce?"}
# ---> 54 response = chain.invoke(question)
#      55 print(response['answer'])
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:3244, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3242 with set_config_context(config) as context:
#    3243     if i == 0:
# -> 3244         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3245     else:
#    3246         input_ = context.run(step.invoke, input_, config)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:4001, in RunnableParallel.invoke(self, input, config, **kwargs)
#    3996     with get_executor_for_config(config) as executor:
#    3997         futures = [
#    3998             executor.submit(_invoke_step, step, input, config, key)
#    3999             for key, step in steps.items()
#    4000         ]
# -> 4001         output = {key: future.result() for key, future in zip(steps, futures)}
#    4002 # finish the root run
#    4003 except BaseException as e:
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /usr/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:3985, in RunnableParallel.invoke.<locals>._invoke_step(step, input_, config, key)
#    3979 child_config = patch_config(
#    3980     config,
#    3981     # mark each step as a child run
#    3982     callbacks=run_manager.get_child(f"map:key:{key}"),
#    3983 )
#    3984 with set_config_context(child_config) as context:
# -> 3985     return context.run(
#    3986         step.invoke,
#    3987         input_,
#    3988         child_config,
#    3989     )
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:3244, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3242 with set_config_context(config) as context:
#    3243     if i == 0:
# -> 3244         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3245     else:
#    3246         input_ = context.run(step.invoke, input_, config)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:5025, in RunnableLambda.invoke(self, input, config, **kwargs)
#    5010 """Invoke this ``Runnable`` synchronously.
#    5011
#    5012 Args:
#    (...)
#    5022
#    5023 """
#    5024 if hasattr(self, "func"):
# -> 5025     return self._call_with_config(
#    5026         self._invoke,
#    5027         input,
#    5028         ensure_config(config),
#    5029         **kwargs,
#    5030     )
#    5031 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    5032 raise TypeError(msg)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:2092, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2088     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2089     with set_config_context(child_config) as context:
#    2090         output = cast(
#    2091             "Output",
# -> 2092             context.run(
#    2093                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2094                 func,
#    2095                 input_,
#    2096                 config,
#    2097                 run_manager,
#    2098                 **kwargs,
#    2099             ),
#    2100         )
#    2101 except BaseException as e:
#    2102     run_manager.on_chain_error(e)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/config.py:430, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     428 if run_manager is not None and accepts_run_manager(func):
#     429     kwargs["run_manager"] = run_manager
# --> 430 return func(input, **kwargs)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:4882, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4880                 output = chunk
#    4881 else:
# -> 4882     output = call_func_with_variable_args(
#    4883         self.func, input_, config, run_manager, **kwargs
#    4884     )
#    4885 # If the output is a Runnable, invoke it
#    4886 if isinstance(output, Runnable):
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/config.py:430, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     428 if run_manager is not None and accepts_run_manager(func):
#     429     kwargs["run_manager"] = run_manager
# --> 430 return func(input, **kwargs)
#
# File <command-7610053130095865>, line 16, in get_retriever.<locals>.retrieve(query, k)
#      14 ## get the vector search index
#      15 vsc = VectorSearchClient(disable_notice=True)
# ---> 16 vs_index = vsc.get_index(endpoint_name=vs_endpoint_name, index_name=vs_index_fullname)
#      18 # get the query vector
#      19 embeddings = DatabricksEmbeddings(endpoint="databricks-gte-large-en")
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/databricks/vector_search/client.py:696, in VectorSearchClient.get_index(self, endpoint_name, index_name)
#     689 """
#     690 Get an index.
#     691
#     692 :param Option[str] endpoint_name: The optional name of the endpoint.
#     693 :param str index_name: The name of the index.
#     694 """
#     695 assert index_name, "Index name must be specified"
# --> 696 resp = RequestUtils.issue_request(
#     697     url=self._get_index_url(endpoint_name, index_name),
#     698     token=self._get_token_for_request(),
#     699     method="GET",
#     700 )
#     701 index_url = resp.get("status", {}).get("index_url")
#     702 response_endpoint_name = resp.get("endpoint_name")
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/databricks/vector_search/utils.py:176, in RequestUtils.issue_request(url, method, token, params, json, verify, auth, data, headers, total_retries, backoff_factor, backoff_jitter)
#     174     response.raise_for_status()
#     175 except Exception as e:
# --> 176     raise Exception(
#     177         f"Response content {response.content}, status_code {response.status_code}"
#     178     )
#     179 return response.json()
#
# Exception: Response content b'{"error_code":"RESOURCE_DOES_NOT_EXIST","message":"Unity Catalog entity dbacademy.labuser12293781_1761690681.lab_pdf_text_managed_vs_index does not exist.","details":[{"@type":"type.googleapis.com/google.rpc.RequestInfo","request_id":"d12f6a55-46e8-45a9-b83f-a7fb78cc6d85","serving_data":""}]}', status_code 404

# %%
from operator import itemgetter
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.runnables import RunnableLambda, RunnableParallel, RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser

# Prompt template
TEMPLATE = """You are an assistant for GENAI teaching class. You are answering questions related to Generative AI and how it impacts humans life. If the question is not related to one of these topics, kindly decline to answer. 
Use the following pieces of context to answer the question at the end:

<context>
{context}
</context>

Question: {input}

Answer:
"""

prompt = ChatPromptTemplate.from_template(TEMPLATE)      

# Helper functions
def format_docs(docs):
    # what the model sees in {context}
    return "\n\n".join(d.page_content for d in docs)

def unwrap(payload):
    # return both answer and normalized context (dicts) like you wanted
    docs = payload["docs"]
    return {
        "answer": payload["answer"],
        "context": [{"metadata": getattr(d, "metadata", {}), "page_content": getattr(d, "page_content", "")}
                    for d in docs],
    }

# ---- build the chain ----
# Step 1: retrieve docs
retrieve = RunnableParallel(input=RunnablePassthrough(), docs=get_retriever())

# Step 2: pass formatted context + input to the model
rag = retrieve | {
    "input": itemgetter("input"),
    "context": RunnableLambda(lambda x: format_docs(x["docs"]))
} | prompt | chat_model | StrOutputParser()

# Keep docs for postprocessing
chain = retrieve | {
    "answer": ({"input": itemgetter("input"), "context": RunnableLambda(lambda x: format_docs(x["docs"]))}
               | prompt | chat_model | StrOutputParser()),
    "docs": itemgetter("docs"),
} | RunnableLambda(unwrap)

# Test the complete RAG solution with sample query
question = {"input": "WWill Generative AI replace humans especially in workfoce?"}
response = chain.invoke(question)
print(response['answer'])
# Out:
# Trace(trace_id=tr-87420f4d5b81ffc9f1d6b3e850977e09)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/databricks/vector_search/utils.py:174, in RequestUtils.issue_request(url, method, token, params, json, verify, auth, data, headers, total_retries, backoff_factor, backoff_jitter)
#     173 try:
# --> 174     response.raise_for_status()
#     175 except Exception as e:
#
# File /databricks/python/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 404 Client Error: Not Found for url: https://oregon.cloud.databricks.com/api/2.0/vector-search/endpoints/vs_endpoint_3/indexes/dbacademy.labuser12293781_1761690681.lab_pdf_text_managed_vs_index
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# File <command-7610053130095870>, line 54
#      52 # Test the complete RAG solution with sample query
#      53 question = {"input": "WWill Generative AI replace humans especially in workfoce?"}
# ---> 54 response = chain.invoke(question)
#      55 print(response['answer'])
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:3244, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3242 with set_config_context(config) as context:
#    3243     if i == 0:
# -> 3244         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3245     else:
#    3246         input_ = context.run(step.invoke, input_, config)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:4001, in RunnableParallel.invoke(self, input, config, **kwargs)
#    3996     with get_executor_for_config(config) as executor:
#    3997         futures = [
#    3998             executor.submit(_invoke_step, step, input, config, key)
#    3999             for key, step in steps.items()
#    4000         ]
# -> 4001         output = {key: future.result() for key, future in zip(steps, futures)}
#    4002 # finish the root run
#    4003 except BaseException as e:
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File /usr/lib/python3.12/concurrent/futures/_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File /usr/lib/python3.12/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:3985, in RunnableParallel.invoke.<locals>._invoke_step(step, input_, config, key)
#    3979 child_config = patch_config(
#    3980     config,
#    3981     # mark each step as a child run
#    3982     callbacks=run_manager.get_child(f"map:key:{key}"),
#    3983 )
#    3984 with set_config_context(child_config) as context:
# -> 3985     return context.run(
#    3986         step.invoke,
#    3987         input_,
#    3988         child_config,
#    3989     )
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:3244, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3242 with set_config_context(config) as context:
#    3243     if i == 0:
# -> 3244         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3245     else:
#    3246         input_ = context.run(step.invoke, input_, config)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:5025, in RunnableLambda.invoke(self, input, config, **kwargs)
#    5010 """Invoke this ``Runnable`` synchronously.
#    5011
#    5012 Args:
#    (...)
#    5022
#    5023 """
#    5024 if hasattr(self, "func"):
# -> 5025     return self._call_with_config(
#    5026         self._invoke,
#    5027         input,
#    5028         ensure_config(config),
#    5029         **kwargs,
#    5030     )
#    5031 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    5032 raise TypeError(msg)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:2092, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2088     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2089     with set_config_context(child_config) as context:
#    2090         output = cast(
#    2091             "Output",
# -> 2092             context.run(
#    2093                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2094                 func,
#    2095                 input_,
#    2096                 config,
#    2097                 run_manager,
#    2098                 **kwargs,
#    2099             ),
#    2100         )
#    2101 except BaseException as e:
#    2102     run_manager.on_chain_error(e)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/config.py:430, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     428 if run_manager is not None and accepts_run_manager(func):
#     429     kwargs["run_manager"] = run_manager
# --> 430 return func(input, **kwargs)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/base.py:4882, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4880                 output = chunk
#    4881 else:
# -> 4882     output = call_func_with_variable_args(
#    4883         self.func, input_, config, run_manager, **kwargs
#    4884     )
#    4885 # If the output is a Runnable, invoke it
#    4886 if isinstance(output, Runnable):
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/langchain_core/runnables/config.py:430, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     428 if run_manager is not None and accepts_run_manager(func):
#     429     kwargs["run_manager"] = run_manager
# --> 430 return func(input, **kwargs)
#
# File <command-7610053130095865>, line 16, in get_retriever.<locals>.retrieve(query, k)
#      14 ## get the vector search index
#      15 vsc = VectorSearchClient(disable_notice=True)
# ---> 16 vs_index = vsc.get_index(endpoint_name=vs_endpoint_name, index_name=vs_index_fullname)
#      18 # get the query vector
#      19 embeddings = DatabricksEmbeddings(endpoint="databricks-gte-large-en")
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/databricks/vector_search/client.py:696, in VectorSearchClient.get_index(self, endpoint_name, index_name)
#     689 """
#     690 Get an index.
#     691
#     692 :param Option[str] endpoint_name: The optional name of the endpoint.
#     693 :param str index_name: The name of the index.
#     694 """
#     695 assert index_name, "Index name must be specified"
# --> 696 resp = RequestUtils.issue_request(
#     697     url=self._get_index_url(endpoint_name, index_name),
#     698     token=self._get_token_for_request(),
#     699     method="GET",
#     700 )
#     701 index_url = resp.get("status", {}).get("index_url")
#     702 response_endpoint_name = resp.get("endpoint_name")
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-4a731afb-071f-4ab1-9fab-1a8f3f7d4ba0/lib/python3.12/site-packages/databricks/vector_search/utils.py:176, in RequestUtils.issue_request(url, method, token, params, json, verify, auth, data, headers, total_retries, backoff_factor, backoff_jitter)
#     174     response.raise_for_status()
#     175 except Exception as e:
# --> 176     raise Exception(
#     177         f"Response content {response.content}, status_code {response.status_code}"
#     178     )
#     179 return response.json()
#
# Exception: Response content b'{"error_code":"RESOURCE_DOES_NOT_EXIST","message":"Unity Catalog entity dbacademy.labuser12293781_1761690681.lab_pdf_text_managed_vs_index does not exist.","details":[{"@type":"type.googleapis.com/google.rpc.RequestInfo","request_id":"f73e2c19-0a04-4f9c-8574-6ebf84d77d7b","serving_data":""}]}', status_code 404

# %% [markdown]
# ##Task 4: Save the Model to Model Registry in Unity Catalog
# **Steps:**
# 1. Register the assembled RAG model in the Model Registry with Unity Catalog.
# 2. Ensure that all necessary dependencies and requirements are included.
# 3. Provide an input example and infer the signature for the model.

# %%
## import necessary libraries
from mlflow.models import infer_signature
import mlflow
import langchain

## set Model Registry URI to Unity Catalog
mlflow.set_registry_uri("databricks-uc")
model_name = f"{DA.catalog_name}.{DA.schema_name}.rag_app_demo4"

## register the assembled RAG model in Model Registry with Unity Catalog
with mlflow.start_run(run_name="rag_app_demo4") as run:
    signature = infer_signature(question, response)
    model_info = mlflow.langchain.log_model(
        chain,
        loader_fn=get_retriever, 
        name="chain",
        registered_model_name=model_name,
        pip_requirements=[
            "mlflow==" + mlflow.__version__,
            "langchain==" + langchain.__version__,
            "databricks-vectorsearch",
        ],
        signature=signature,
        input_example=question
    )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-7610053130095872>, line 12
#      10 ## register the assembled RAG model in Model Registry with Unity Catalog
#      11 with mlflow.start_run(run_name="rag_app_demo4") as run:
# ---> 12     signature = infer_signature(question, response)
#      13     model_info = mlflow.langchain.log_model(
#      14         chain,
#      15         loader_fn=get_retriever,
#    (...)
#      24         input_example=question
#      25     )
#
# NameError: name 'response' is not defined

# %% [markdown]
# ## Clean up Resources
#
# This was the final lab. You can delete all resources created in this course.

# %% [markdown]
# ## Conclusion
#
# In this lab, you learned how to assemble a Retrieval-augmented Generation (RAG) application using Databricks components. By integrating Vector Search for document retrieval and a foundational model for response generation, you created a powerful tool for answering user queries. This lab provided hands-on experience in building end-to-end AI applications and demonstrated the capabilities of Databricks for natural language processing tasks.

# %% [markdown]
# &copy; 2025 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
